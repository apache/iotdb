# %%
import matplotlib.pyplot as plt

# %%
with open("./replica_dead.txt", "r") as f:
    data = f.read()

# %%
data_split = data.split('\n')

# %%
data.find("deadCost")
# Out:
# 36524

# %%
ori_data = data[:36524]

# %%
dead_data = data[36533:]

# %%
ori_data=ori_data.split('\n')[1:-1]

# %%
len(dead_data.split("\n")[-1])
# Out:
# 16

# %%
dead_data.split("\n")[-1]
# Out:
# '59.1065673828125'

# %%
dead_data = dead_data.split("\n")

# %%
dead_data[-1]
# Out:
# '59.1065673828125'

# %%
ori_data = list(map(lambda x:float(x), ori_data))

# %%
len(ori_data)
# Out:
# 2000

# %%
dead_data = list(map(lambda x:float(x), dead_data))

# %%
# Out:
# [632.9471435546875,
#  237.1956787109375,
#  145.8579864501953,
#  282.3298034667969,
#  321.2649230957031,
#  785.0289306640625,
#  235.679931640625,
#  25.429046630859375,
#  206.97389221191406,
#  138.42333984375,
#  432.005615234375,
#  412.34130859375,
#  694.5487060546875,
#  428.537841796875,
#  219.5098114013672,
#  452.05859375,
#  129.3831024169922,
#  376.21575927734375,
#  853.732421875,
#  306.2326354980469,
#  223.37789916992188,
#  513.3457641601562,
#  185.8403778076172,
#  260.392578125,
#  560.0101928710938,
#  1525.0791015625,
#  145.91244506835938,
#  151.16712951660156,
#  569.8364868164062,
#  960.16162109375,
#  33.05059814453125,
#  1661.7794189453125,
#  1274.654052734375,
#  277.94427490234375,
#  667.3555297851562,
#  1099.8206787109375,
#  575.1738891601562,
#  263.4745178222656,
#  185.55421447753906,
#  321.3957214355469,
#  1025.6265869140625,
#  201.73008728027344,
#  256.34051513671875,
#  231.18931579589844,
#  252.7527618408203,
# ...

# %%
import numpy as np

# %%
x = np.arange(len(ori_data))

# %%
x
# Out:
# array([   0,    1,    2, ..., 1997, 1998, 1999])

# %%
plt.plot(x, ori_data, label="ori")

# %%
plt.plot(x, [dead_data, ori_data], label="dead")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-256f1f1a68b8> in <module>
# ----> 1 plt.plot(x, [dead_data, ori_data], label="dead")
#
# d:\programfiles\python\python36\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2824     return gca().plot(
#    2825         *args, scalex=scalex, scaley=scaley,
# -> 2826         **({"data": data} if data is not None else {}), **kwargs)
#    2827
#    2828
#
# d:\programfiles\python\python36\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ...

# %%
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.show()
